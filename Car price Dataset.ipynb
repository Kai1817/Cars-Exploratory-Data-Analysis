# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df= pd.read_csv('C:/Users/asus/OneDrive/Desktop/CarPrice_Assignment.csv')

# %%
"""Shows all the columns and rows"""

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df
# Out:
#      car_ID  symboling                          CarName fueltype aspiration  \
# 0         1          3               alfa-romero giulia      gas        std
# 1         2          3              alfa-romero stelvio      gas        std
# 2         3          1         alfa-romero Quadrifoglio      gas        std
# 3         4          2                      audi 100 ls      gas        std
# 4         5          2                       audi 100ls      gas        std
# 5         6          2                         audi fox      gas        std
# 6         7          1                       audi 100ls      gas        std
# 7         8          1                        audi 5000      gas        std
# 8         9          1                        audi 4000      gas      turbo
# 9        10          0              audi 5000s (diesel)      gas      turbo
# 10       11          2                         bmw 320i      gas        std
# 11       12          0                         bmw 320i      gas        std
# 12       13          0                           bmw x1      gas        std
# 13       14          0                           bmw x3      gas        std
# 14       15          1                           bmw z4      gas        std
# 15       16          0                           bmw x4      gas        std
# 16       17          0                           bmw x5      gas        std
# 17       18          0                           bmw x3      gas        std
# 18       19          2                 chevrolet impala      gas        std
# 19       20          1            chevrolet monte carlo      gas        std
# 20       21          0              chevrolet vega 2300      gas        std
# 21       22          1                    dodge rampage      gas        std
# 22       23          1              dodge challenger se      gas        std
# 23       24          1                       dodge d200      gas      turbo
# 24       25          1                dodge monaco (sw)      gas        std
# 25       26          1               dodge colt hardtop      gas        std
# 26       27          1                  dodge colt (sw)      gas        std
# 27       28          1             dodge coronet custom      gas      turbo
# 28       29         -1                dodge dart custom      gas        std
# 29       30          3        dodge coronet custom (sw)      gas      turbo
# 30       31          2                      honda civic      gas        std
# 31       32          2                 honda civic cvcc      gas        std
# 32       33          1                      honda civic      gas        std
# 33       34          1                honda accord cvcc      gas        std
# 34       35          1                 honda civic cvcc      gas        std
# 35       36          0                  honda accord lx      gas        std
# 36       37          0              honda civic 1500 gl      gas        std
# 37       38          0                     honda accord      gas        std
# 38       39          0                 honda civic 1300      gas        std
# 39       40          0                    honda prelude      gas        std
# 40       41          0                     honda accord      gas        std
# 41       42          0                      honda civic      gas        std
# 42       43          1               honda civic (auto)      gas        std
# 43       44          0                       isuzu MU-X      gas        std
# 44       45          1                     isuzu D-Max       gas        std
# 45       46          0              isuzu D-Max V-Cross      gas        std
# 46       47          2                     isuzu D-Max       gas        std
# 47       48          0                        jaguar xj      gas        std
# 48       49          0                        jaguar xf      gas        std
# 49       50          0                        jaguar xk      gas        std
# 50       51          1                        maxda rx3      gas        std
# 51       52          1                 maxda glc deluxe      gas        std
# 52       53          1                  mazda rx2 coupe      gas        std
# 53       54          1                       mazda rx-4      gas        std
# 54       55          1                 mazda glc deluxe      gas        std
# 55       56          3                        mazda 626      gas        std
# 56       57          3                        mazda glc      gas        std
# 57       58          3                    mazda rx-7 gs      gas        std
# 58       59          3                      mazda glc 4      gas        std
# 59       60          1                        mazda 626      gas        std
# 60       61          0               mazda glc custom l      gas        std
# 61       62          1                 mazda glc custom      gas        std
# 62       63          0                       mazda rx-4      gas        std
# 63       64          0                 mazda glc deluxe   diesel        std
# 64       65          0                        mazda 626      gas        std
# 65       66          0                        mazda glc      gas        std
# 66       67          0                    mazda rx-7 gs   diesel        std
# 67       68         -1         buick electra 225 custom   diesel      turbo
# 68       69         -1         buick century luxus (sw)   diesel      turbo
# 69       70          0                    buick century   diesel      turbo
# 70       71         -1                    buick skyhawk   diesel      turbo
# 71       72         -1          buick opel isuzu deluxe      gas        std
# 72       73          3                    buick skylark      gas        std
# 73       74          0            buick century special      gas        std
# 74       75          1  buick regal sport coupe (turbo)      gas        std
# 75       76          1                   mercury cougar      gas      turbo
# 76       77          2                mitsubishi mirage      gas        std
# 77       78          2                mitsubishi lancer      gas        std
# 78       79          2             mitsubishi outlander      gas        std
# 79       80          1                    mitsubishi g4      gas      turbo
# 80       81          3             mitsubishi mirage g4      gas      turbo
# 81       82          3                    mitsubishi g4      gas        std
# 82       83          3             mitsubishi outlander      gas      turbo
# 83       84          3                    mitsubishi g4      gas      turbo
# 84       85          3             mitsubishi mirage g4      gas      turbo
# 85       86          1               mitsubishi montero      gas        std
# 86       87          1                mitsubishi pajero      gas        std
# 87       88          1             mitsubishi outlander      gas      turbo
# 88       89         -1             mitsubishi mirage g4      gas        std
# 89       90          1                     Nissan versa      gas        std
# 90       91          1                      nissan gt-r   diesel        std
# 91       92          1                     nissan rogue      gas        std
# 92       93          1                     nissan latio      gas        std
# 93       94          1                     nissan titan      gas        std
# 94       95          1                      nissan leaf      gas        std
# 95       96          1                      nissan juke      gas        std
# 96       97          1                     nissan latio      gas        std
# 97       98          1                      nissan note      gas        std
# 98       99          2                   nissan clipper      gas        std
# 99      100          0                     nissan rogue      gas        std
# 100     101          0                     nissan nv200      gas        std
# 101     102          0                      nissan dayz      gas        std
# 102     103          0                      nissan fuga      gas        std
# 103     104          0                      nissan otti      gas        std
# 104     105          3                     nissan teana      gas        std
# 105     106          3                     nissan kicks      gas      turbo
# 106     107          1                   nissan clipper      gas        std
# 107     108          0                      peugeot 504      gas        std
# 108     109          0                      peugeot 304   diesel      turbo
# 109     110          0                 peugeot 504 (sw)      gas        std
# 110     111          0                      peugeot 504   diesel      turbo
# 111     112          0                      peugeot 504      gas        std
# 112     113          0                    peugeot 604sl   diesel      turbo
# 113     114          0                      peugeot 504      gas        std
# 114     115          0        peugeot 505s turbo diesel   diesel      turbo
# 115     116          0                      peugeot 504      gas        std
# 116     117          0                      peugeot 504   diesel      turbo
# 117     118          0                    peugeot 604sl      gas      turbo
# 118     119          1                plymouth fury iii      gas        std
# 119     120          1                 plymouth cricket      gas      turbo
# 120     121          1                plymouth fury iii      gas        std
# 121     122          1   plymouth satellite custom (sw)      gas        std
# 122     123          1         plymouth fury gran sedan      gas        std
# 123     124         -1                 plymouth valiant      gas        std
# 124     125          3                  plymouth duster      gas      turbo
# 125     126          3                    porsche macan      gas        std
# 126     127          3                porcshce panamera      gas        std
# 127     128          3                  porsche cayenne      gas        std
# 128     129          3                   porsche boxter      gas        std
# 129     130          1                  porsche cayenne      gas        std
# 130     131          0                     renault 12tl      gas        std
# 131     132          2                    renault 5 gtl      gas        std
# 132     133          3                         saab 99e      gas        std
# 133     134          2                        saab 99le      gas        std
# 134     135          3                        saab 99le      gas        std
# 135     136          2                       saab 99gle      gas        std
# 136     137          3                       saab 99gle      gas      turbo
# 137     138          2                         saab 99e      gas      turbo
# 138     139          2                           subaru      gas        std
# 139     140          2                        subaru dl      gas        std
# 140     141          2                        subaru dl      gas        std
# 141     142          0                           subaru      gas        std
# 142     143          0                       subaru brz      gas        std
# 143     144          0                      subaru baja      gas        std
# 144     145          0                        subaru r1      gas        std
# 145     146          0                        subaru r2      gas      turbo
# 146     147          0                    subaru trezia      gas        std
# 147     148          0                   subaru tribeca      gas        std
# 148     149          0                        subaru dl      gas        std
# 149     150          0                        subaru dl      gas      turbo
# 150     151          1            toyota corona mark ii      gas        std
# 151     152          1                    toyota corona      gas        std
# 152     153          1              toyota corolla 1200      gas        std
# 153     154          0            toyota corona hardtop      gas        std
# 154     155          0         toyota corolla 1600 (sw)      gas        std
# 155     156          0                    toyota carina      gas        std
# 156     157          0                   toyota mark ii      gas        std
# 157     158          0              toyota corolla 1200      gas        std
# 158     159          0                    toyota corona   diesel        std
# 159     160          0                   toyota corolla   diesel        std
# 160     161          0                    toyota corona      gas        std
# 161     162          0                   toyota corolla      gas        std
# 162     163          0                   toyota mark ii      gas        std
# 163     164          1          toyota corolla liftback      gas        std
# 164     165          1                    toyota corona      gas        std
# 165     166          1        toyota celica gt liftback      gas        std
# 166     167          1            toyota corolla tercel      gas        std
# 167     168          2           toyota corona liftback      gas        std
# 168     169          2                   toyota corolla      gas        std
# 169     170          2                   toyota starlet      gas        std
# 170     171          2                    toyota tercel      gas        std
# 171     172          2                   toyota corolla      gas        std
# 172     173          2                  toyota cressida      gas        std
# 173     174         -1                   toyota corolla      gas        std
# 174     175         -1                 toyota celica gt   diesel      turbo
# 175     176         -1                    toyota corona      gas        std
# 176     177         -1                   toyota corolla      gas        std
# 177     178         -1                   toyota mark ii      gas        std
# 178     179          3          toyota corolla liftback      gas        std
# 179     180          3                    toyota corona      gas        std
# 180     181         -1                   toyota starlet      gas        std
# 181     182         -1                   toyouta tercel      gas        std
# 182     183          2                 vokswagen rabbit   diesel        std
# 183     184          2     volkswagen 1131 deluxe sedan      gas        std
# 184     185          2             volkswagen model 111   diesel        std
# 185     186          2                volkswagen type 3      gas        std
# 186     187          2              volkswagen 411 (sw)      gas        std
# 187     188          2          volkswagen super beetle   diesel      turbo
# 188     189          2                volkswagen dasher      gas        std
# 189     190          3                        vw dasher      gas        std
# 190     191          3                        vw rabbit      gas        std
# 191     192          0                volkswagen rabbit      gas        std
# 192     193          0         volkswagen rabbit custom   diesel      turbo
# 193     194          0                volkswagen dasher      gas        std
# 194     195         -2                  volvo 145e (sw)      gas        std
# 195     196         -1                      volvo 144ea      gas        std
# 196     197         -2                      volvo 244dl      gas        std
# 197     198         -1                        volvo 245      gas        std
# 198     199         -2                      volvo 264gl      gas      turbo
# 199     200         -1                     volvo diesel      gas      turbo
# 200     201         -1                  volvo 145e (sw)      gas        std
# 201     202         -1                      volvo 144ea      gas      turbo
# 202     203         -1                      volvo 244dl      gas        std
# 203     204         -1                        volvo 246   diesel      turbo
# 204     205         -1                      volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  carlength  \
# 0          two  convertible        rwd          front       88.6      168.8
# 1          two  convertible        rwd          front       88.6      168.8
# 2          two    hatchback        rwd          front       94.5      171.2
# 3         four        sedan        fwd          front       99.8      176.6
# 4         four        sedan        4wd          front       99.4      176.6
# 5          two        sedan        fwd          front       99.8      177.3
# 6         four        sedan        fwd          front      105.8      192.7
# 7         four        wagon        fwd          front      105.8      192.7
# 8         four        sedan        fwd          front      105.8      192.7
# 9          two    hatchback        4wd          front       99.5      178.2
# 10         two        sedan        rwd          front      101.2      176.8
# 11        four        sedan        rwd          front      101.2      176.8
# 12         two        sedan        rwd          front      101.2      176.8
# 13        four        sedan        rwd          front      101.2      176.8
# 14        four        sedan        rwd          front      103.5      189.0
# 15        four        sedan        rwd          front      103.5      189.0
# 16         two        sedan        rwd          front      103.5      193.8
# 17        four        sedan        rwd          front      110.0      197.0
# 18         two    hatchback        fwd          front       88.4      141.1
# 19         two    hatchback        fwd          front       94.5      155.9
# 20        four        sedan        fwd          front       94.5      158.8
# 21         two    hatchback        fwd          front       93.7      157.3
# 22         two    hatchback        fwd          front       93.7      157.3
# 23         two    hatchback        fwd          front       93.7      157.3
# 24        four    hatchback        fwd          front       93.7      157.3
# 25        four        sedan        fwd          front       93.7      157.3
# 26        four        sedan        fwd          front       93.7      157.3
# 27         two        sedan        fwd          front       93.7      157.3
# 28        four        wagon        fwd          front      103.3      174.6
# 29         two    hatchback        fwd          front       95.9      173.2
# 30         two    hatchback        fwd          front       86.6      144.6
# 31         two    hatchback        fwd          front       86.6      144.6
# 32         two    hatchback        fwd          front       93.7      150.0
# 33         two    hatchback        fwd          front       93.7      150.0
# 34         two    hatchback        fwd          front       93.7      150.0
# 35        four        sedan        fwd          front       96.5      163.4
# 36        four        wagon        fwd          front       96.5      157.1
# 37         two    hatchback        fwd          front       96.5      167.5
# 38         two    hatchback        fwd          front       96.5      167.5
# 39        four        sedan        fwd          front       96.5      175.4
# 40        four        sedan        fwd          front       96.5      175.4
# 41        four        sedan        fwd          front       96.5      175.4
# 42         two        sedan        fwd          front       96.5      169.1
# 43        four        sedan        rwd          front       94.3      170.7
# 44         two        sedan        fwd          front       94.5      155.9
# 45        four        sedan        fwd          front       94.5      155.9
# 46         two    hatchback        rwd          front       96.0      172.6
# 47        four        sedan        rwd          front      113.0      199.6
# 48        four        sedan        rwd          front      113.0      199.6
# 49         two        sedan        rwd          front      102.0      191.7
# 50         two    hatchback        fwd          front       93.1      159.1
# 51         two    hatchback        fwd          front       93.1      159.1
# 52         two    hatchback        fwd          front       93.1      159.1
# 53        four        sedan        fwd          front       93.1      166.8
# 54        four        sedan        fwd          front       93.1      166.8
# 55         two    hatchback        rwd          front       95.3      169.0
# 56         two    hatchback        rwd          front       95.3      169.0
# 57         two    hatchback        rwd          front       95.3      169.0
# 58         two    hatchback        rwd          front       95.3      169.0
# 59         two    hatchback        fwd          front       98.8      177.8
# 60        four        sedan        fwd          front       98.8      177.8
# 61         two    hatchback        fwd          front       98.8      177.8
# 62        four        sedan        fwd          front       98.8      177.8
# 63        four        sedan        fwd          front       98.8      177.8
# 64        four    hatchback        fwd          front       98.8      177.8
# 65        four        sedan        rwd          front      104.9      175.0
# 66        four        sedan        rwd          front      104.9      175.0
# 67        four        sedan        rwd          front      110.0      190.9
# 68        four        wagon        rwd          front      110.0      190.9
# 69         two      hardtop        rwd          front      106.7      187.5
# 70        four        sedan        rwd          front      115.6      202.6
# 71        four        sedan        rwd          front      115.6      202.6
# 72         two  convertible        rwd          front       96.6      180.3
# 73        four        sedan        rwd          front      120.9      208.1
# 74         two      hardtop        rwd          front      112.0      199.2
# 75         two    hatchback        rwd          front      102.7      178.4
# 76         two    hatchback        fwd          front       93.7      157.3
# 77         two    hatchback        fwd          front       93.7      157.3
# 78         two    hatchback        fwd          front       93.7      157.3
# 79         two    hatchback        fwd          front       93.0      157.3
# 80         two    hatchback        fwd          front       96.3      173.0
# 81         two    hatchback        fwd          front       96.3      173.0
# 82         two    hatchback        fwd          front       95.9      173.2
# 83         two    hatchback        fwd          front       95.9      173.2
# 84         two    hatchback        fwd          front       95.9      173.2
# 85        four        sedan        fwd          front       96.3      172.4
# 86        four        sedan        fwd          front       96.3      172.4
# 87        four        sedan        fwd          front       96.3      172.4
# 88        four        sedan        fwd          front       96.3      172.4
# 89         two        sedan        fwd          front       94.5      165.3
# 90         two        sedan        fwd          front       94.5      165.3
# 91         two        sedan        fwd          front       94.5      165.3
# 92        four        sedan        fwd          front       94.5      165.3
# 93        four        wagon        fwd          front       94.5      170.2
# 94         two        sedan        fwd          front       94.5      165.3
# 95         two    hatchback        fwd          front       94.5      165.6
# 96        four        sedan        fwd          front       94.5      165.3
# 97        four        wagon        fwd          front       94.5      170.2
# 98         two      hardtop        fwd          front       95.1      162.4
# 99        four    hatchback        fwd          front       97.2      173.4
# 100       four        sedan        fwd          front       97.2      173.4
# 101       four        sedan        fwd          front      100.4      181.7
# 102       four        wagon        fwd          front      100.4      184.6
# 103       four        sedan        fwd          front      100.4      184.6
# 104        two    hatchback        rwd          front       91.3      170.7
# 105        two    hatchback        rwd          front       91.3      170.7
# 106        two    hatchback        rwd          front       99.2      178.5
# 107       four        sedan        rwd          front      107.9      186.7
# 108       four        sedan        rwd          front      107.9      186.7
# 109       four        wagon        rwd          front      114.2      198.9
# 110       four        wagon        rwd          front      114.2      198.9
# 111       four        sedan        rwd          front      107.9      186.7
# 112       four        sedan        rwd          front      107.9      186.7
# 113       four        wagon        rwd          front      114.2      198.9
# 114       four        wagon        rwd          front      114.2      198.9
# 115       four        sedan        rwd          front      107.9      186.7
# 116       four        sedan        rwd          front      107.9      186.7
# 117       four        sedan        rwd          front      108.0      186.7
# 118        two    hatchback        fwd          front       93.7      157.3
# 119        two    hatchback        fwd          front       93.7      157.3
# 120       four    hatchback        fwd          front       93.7      157.3
# 121       four        sedan        fwd          front       93.7      167.3
# 122       four        sedan        fwd          front       93.7      167.3
# 123       four        wagon        fwd          front      103.3      174.6
# 124        two    hatchback        rwd          front       95.9      173.2
# 125        two    hatchback        rwd          front       94.5      168.9
# 126        two      hardtop        rwd           rear       89.5      168.9
# 127        two      hardtop        rwd           rear       89.5      168.9
# 128        two  convertible        rwd           rear       89.5      168.9
# 129        two    hatchback        rwd          front       98.4      175.7
# 130       four        wagon        fwd          front       96.1      181.5
# 131        two    hatchback        fwd          front       96.1      176.8
# 132        two    hatchback        fwd          front       99.1      186.6
# 133       four        sedan        fwd          front       99.1      186.6
# 134        two    hatchback        fwd          front       99.1      186.6
# 135       four        sedan        fwd          front       99.1      186.6
# 136        two    hatchback        fwd          front       99.1      186.6
# 137       four        sedan        fwd          front       99.1      186.6
# 138        two    hatchback        fwd          front       93.7      156.9
# 139        two    hatchback        fwd          front       93.7      157.9
# 140        two    hatchback        4wd          front       93.3      157.3
# 141       four        sedan        fwd          front       97.2      172.0
# 142       four        sedan        fwd          front       97.2      172.0
# 143       four        sedan        fwd          front       97.2      172.0
# 144       four        sedan        4wd          front       97.0      172.0
# 145       four        sedan        4wd          front       97.0      172.0
# 146       four        wagon        fwd          front       97.0      173.5
# 147       four        wagon        fwd          front       97.0      173.5
# 148       four        wagon        4wd          front       96.9      173.6
# 149       four        wagon        4wd          front       96.9      173.6
# 150        two    hatchback        fwd          front       95.7      158.7
# 151        two    hatchback        fwd          front       95.7      158.7
# 152       four    hatchback        fwd          front       95.7      158.7
# 153       four        wagon        fwd          front       95.7      169.7
# 154       four        wagon        4wd          front       95.7      169.7
# 155       four        wagon        4wd          front       95.7      169.7
# 156       four        sedan        fwd          front       95.7      166.3
# 157       four    hatchback        fwd          front       95.7      166.3
# 158       four        sedan        fwd          front       95.7      166.3
# 159       four    hatchback        fwd          front       95.7      166.3
# 160       four        sedan        fwd          front       95.7      166.3
# 161       four    hatchback        fwd          front       95.7      166.3
# 162       four        sedan        fwd          front       95.7      166.3
# 163        two        sedan        rwd          front       94.5      168.7
# 164        two    hatchback        rwd          front       94.5      168.7
# 165        two        sedan        rwd          front       94.5      168.7
# 166        two    hatchback        rwd          front       94.5      168.7
# 167        two      hardtop        rwd          front       98.4      176.2
# 168        two      hardtop        rwd          front       98.4      176.2
# 169        two    hatchback        rwd          front       98.4      176.2
# 170        two      hardtop        rwd          front       98.4      176.2
# 171        two    hatchback        rwd          front       98.4      176.2
# 172        two  convertible        rwd          front       98.4      176.2
# 173       four        sedan        fwd          front      102.4      175.6
# 174       four        sedan        fwd          front      102.4      175.6
# 175       four    hatchback        fwd          front      102.4      175.6
# 176       four        sedan        fwd          front      102.4      175.6
# 177       four    hatchback        fwd          front      102.4      175.6
# 178        two    hatchback        rwd          front      102.9      183.5
# 179        two    hatchback        rwd          front      102.9      183.5
# 180       four        sedan        rwd          front      104.5      187.8
# 181       four        wagon        rwd          front      104.5      187.8
# 182        two        sedan        fwd          front       97.3      171.7
# 183        two        sedan        fwd          front       97.3      171.7
# 184       four        sedan        fwd          front       97.3      171.7
# 185       four        sedan        fwd          front       97.3      171.7
# 186       four        sedan        fwd          front       97.3      171.7
# 187       four        sedan        fwd          front       97.3      171.7
# 188       four        sedan        fwd          front       97.3      171.7
# 189        two  convertible        fwd          front       94.5      159.3
# 190        two    hatchback        fwd          front       94.5      165.7
# 191       four        sedan        fwd          front      100.4      180.2
# 192       four        sedan        fwd          front      100.4      180.2
# 193       four        wagon        fwd          front      100.4      183.1
# 194       four        sedan        rwd          front      104.3      188.8
# 195       four        wagon        rwd          front      104.3      188.8
# 196       four        sedan        rwd          front      104.3      188.8
# 197       four        wagon        rwd          front      104.3      188.8
# 198       four        sedan        rwd          front      104.3      188.8
# 199       four        wagon        rwd          front      104.3      188.8
# 200       four        sedan        rwd          front      109.1      188.8
# 201       four        sedan        rwd          front      109.1      188.8
# 202       four        sedan        rwd          front      109.1      188.8
# 203       four        sedan        rwd          front      109.1      188.8
# 204       four        sedan        rwd          front      109.1      188.8
#
#      carwidth  carheight  curbweight enginetype cylindernumber  enginesize  \
# 0        64.1       48.8        2548       dohc           four         130
# 1        64.1       48.8        2548       dohc           four         130
# 2        65.5       52.4        2823       ohcv            six         152
# 3        66.2       54.3        2337        ohc           four         109
# 4        66.4       54.3        2824        ohc           five         136
# 5        66.3       53.1        2507        ohc           five         136
# 6        71.4       55.7        2844        ohc           five         136
# 7        71.4       55.7        2954        ohc           five         136
# 8        71.4       55.9        3086        ohc           five         131
# 9        67.9       52.0        3053        ohc           five         131
# 10       64.8       54.3        2395        ohc           four         108
# 11       64.8       54.3        2395        ohc           four         108
# 12       64.8       54.3        2710        ohc            six         164
# 13       64.8       54.3        2765        ohc            six         164
# 14       66.9       55.7        3055        ohc            six         164
# 15       66.9       55.7        3230        ohc            six         209
# 16       67.9       53.7        3380        ohc            six         209
# 17       70.9       56.3        3505        ohc            six         209
# 18       60.3       53.2        1488          l          three          61
# 19       63.6       52.0        1874        ohc           four          90
# 20       63.6       52.0        1909        ohc           four          90
# 21       63.8       50.8        1876        ohc           four          90
# 22       63.8       50.8        1876        ohc           four          90
# 23       63.8       50.8        2128        ohc           four          98
# 24       63.8       50.6        1967        ohc           four          90
# 25       63.8       50.6        1989        ohc           four          90
# 26       63.8       50.6        1989        ohc           four          90
# 27       63.8       50.6        2191        ohc           four          98
# 28       64.6       59.8        2535        ohc           four         122
# 29       66.3       50.2        2811        ohc           four         156
# 30       63.9       50.8        1713        ohc           four          92
# 31       63.9       50.8        1819        ohc           four          92
# 32       64.0       52.6        1837        ohc           four          79
# 126       mpfi       3.74   2.900              9.50         207     5900
# 127       mpfi       3.74   2.900              9.50         207     5900
# 128       mpfi       3.74   2.900              9.50         207     5900
# 129       mpfi       3.94   3.110             10.00         288     5750
# 130       mpfi       3.46   3.900              8.70          90     5100
# 131       mpfi       3.46   3.900              8.70          90     5100
# 132       mpfi       3.54   3.070              9.31         110     5250
# 133       mpfi       3.54   3.070              9.30         110     5250
# 134       mpfi       2.54   2.070              9.30         110     5250
# 135       mpfi       3.54   3.070              9.30         110     5250
# 136       mpfi       3.54   3.070              9.00         160     5500
# 137       mpfi       3.54   3.070              9.00         160     5500
# 138       2bbl       3.62   2.360              9.00          69     4900
# 139       2bbl       3.62   2.640              8.70          73     4400
# 140       2bbl       3.62   2.640              8.70          73     4400
# 141       2bbl       3.62   2.640              9.50          82     4800
# 142       2bbl       3.62   2.640              9.50          82     4400
# 143       mpfi       3.62   2.640              9.00          94     5200
# 144       2bbl       3.62   2.640              9.00          82     4800
# 145       mpfi       3.62   2.640              7.70         111     4800
# 146       2bbl       3.62   2.640              9.00          82     4800
# 147       mpfi       3.62   2.640              9.00          94     5200
# 148       2bbl       3.62   2.640              9.00          82     4800
# 149       mpfi       3.62   2.640              7.70         111     4800
# 150       2bbl       3.05   3.030              9.00          62     4800
# 151       2bbl       3.05   3.030              9.00          62     4800
# 152       2bbl       3.05   3.030              9.00          62     4800
# 153       2bbl       3.05   3.030              9.00          62     4800
# 154       2bbl       3.05   3.030              9.00          62     4800
# 155       2bbl       3.05   3.030              9.00          62     4800
# 156       2bbl       3.19   3.030              9.00          70     4800
# 157       2bbl       3.19   3.030              9.00          70     4800
# 158        idi       3.27   3.350             22.50          56     4500
# 159        idi       3.27   3.350             22.50          56     4500
# 160       2bbl       3.19   3.030              9.00          70     4800
# 161       2bbl       3.19   3.030              9.00          70     4800
# 162       2bbl       3.19   3.030              9.00          70     4800
# 163       2bbl       3.19   3.030              9.00          70     4800
# 164       2bbl       3.19   3.030              9.00          70     4800
# 165       mpfi       3.24   3.080              9.40         112     6600
# 166       mpfi       3.24   3.080              9.40         112     6600
# 167       mpfi       3.62   3.500              9.30         116     4800
# 168       mpfi       3.62   3.500              9.30         116     4800
# 169       mpfi       3.62   3.500              9.30         116     4800
# 170       mpfi       3.62   3.500              9.30         116     4800
# 171       mpfi       3.62   3.500              9.30         116     4800
# 172       mpfi       3.62   3.500              9.30         116     4800
# 173       mpfi       3.31   3.540              8.70          92     4200
# 174        idi       3.27   3.350             22.50          73     4500
# 175       mpfi       3.31   3.540              8.70          92     4200
# 176       mpfi       3.31   3.540              8.70          92     4200
# 177       mpfi       3.31   3.540              8.70          92     4200
# 178       mpfi       3.27   3.350              9.30         161     5200
# 179       mpfi       3.27   3.350              9.30         161     5200
# 180       mpfi       3.27   3.350              9.20         156     5200
# 181       mpfi       3.27   3.350              9.20         156     5200
# 182        idi       3.01   3.400             23.00          52     4800
# 183       mpfi       3.19   3.400              9.00          85     5250
# 184        idi       3.01   3.400             23.00          52     4800
# 190       24          29   9980.000
# 191       19          24  13295.000
# 192       33          38  13845.000
# 193       25          31  12290.000
# 194       23          28  12940.000
# 195       23          28  13415.000
# 196       24          28  15985.000
# 197       24          28  16515.000
# 198       17          22  18420.000
# 199       17          22  18950.000
# 200       23          28  16845.000
# 201       19          25  19045.000
# 202       18          23  21485.000
# 203       26          27  22470.000
# 204       19          25  22625.000

# %%
"""Reset to normal settings for the dataframe showing."""
pd.reset_option('max_columns')
pd.reset_option('max_rows')
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0          two  convertible        rwd          front       88.6  ...
# 1          two  convertible        rwd          front       88.6  ...
# 2          two    hatchback        rwd          front       94.5  ...
# 3         four        sedan        fwd          front       99.8  ...
# 4         four        sedan        4wd          front       99.4  ...
# ..         ...          ...        ...            ...        ...  ...
# 200       four        sedan        rwd          front      109.1  ...
# 201       four        sedan        rwd          front      109.1  ...
# 202       four        sedan        rwd          front      109.1  ...
# 203       four        sedan        rwd          front      109.1  ...
# 204       four        sedan        rwd          front      109.1  ...
#
#      enginesize  fuelsystem  boreratio  stroke compressionratio horsepower  \
# 0           130        mpfi       3.47    2.68              9.0        111
# 1           130        mpfi       3.47    2.68              9.0        111
# 2           152        mpfi       2.68    3.47              9.0        154
# 3           109        mpfi       3.19    3.40             10.0        102
# 4           136        mpfi       3.19    3.40              8.0        115
# ..          ...         ...        ...     ...              ...        ...
# 200         141        mpfi       3.78    3.15              9.5        114
# 201         141        mpfi       3.78    3.15              8.7        160
# 202         173        mpfi       3.58    2.87              8.8        134
# 203         145         idi       3.01    3.40             23.0        106
# 204         141        mpfi       3.78    3.15              9.5        114
#
#      peakrpm citympg  highwaympg    price
# 0       5000      21          27  13495.0
# 1       5000      21          27  16500.0
# 2       5000      19          26  16500.0
# 3       5500      24          30  13950.0
# 4       5500      18          22  17450.0
# ..       ...     ...         ...      ...
# 200     5400      23          28  16845.0
# 201     5300      19          25  19045.0
# 202     5500      18          23  21485.0
# 203     4800      26          27  22470.0
# 204     5400      19          25  22625.0
#
# [205 rows x 26 columns]

# %% [markdown]
# #### checking the names of columns

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %% [markdown]
# #### check wether there are null values present in any column or not.

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %% [markdown]
# #### dropping Car_id column as its of no use

# %%
df.drop(columns=['car_ID'],inplace=True)

# %%
df
# Out:
#      symboling                   CarName fueltype aspiration doornumber  \
# 0            3        alfa-romero giulia      gas        std        two
# 1            3       alfa-romero stelvio      gas        std        two
# 2            1  alfa-romero Quadrifoglio      gas        std        two
# 3            2               audi 100 ls      gas        std       four
# 4            2                audi 100ls      gas        std       four
# ..         ...                       ...      ...        ...        ...
# 200         -1           volvo 145e (sw)      gas        std       four
# 201         -1               volvo 144ea      gas      turbo       four
# 202         -1               volvo 244dl      gas        std       four
# 203         -1                 volvo 246   diesel      turbo       four
# 204         -1               volvo 264gl      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0    convertible        rwd          front       88.6      168.8  ...
# 1    convertible        rwd          front       88.6      168.8  ...
# 2      hatchback        rwd          front       94.5      171.2  ...
# 3          sedan        fwd          front       99.8      176.6  ...
# 4          sedan        4wd          front       99.4      176.6  ...
# ..           ...        ...            ...        ...        ...  ...
# 200        sedan        rwd          front      109.1      188.8  ...
# 201        sedan        rwd          front      109.1      188.8  ...
# 202        sedan        rwd          front      109.1      188.8  ...
# 203        sedan        rwd          front      109.1      188.8  ...
# 204        sedan        rwd          front      109.1      188.8  ...
#
#      enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# 0           130        mpfi       3.47   2.68              9.0         111
# 1           130        mpfi       3.47   2.68              9.0         111
# 2           152        mpfi       2.68   3.47              9.0         154
# 3           109        mpfi       3.19   3.40             10.0         102
# 4           136        mpfi       3.19   3.40              8.0         115
# ..          ...         ...        ...    ...              ...         ...
# 200         141        mpfi       3.78   3.15              9.5         114
# 201         141        mpfi       3.78   3.15              8.7         160
# 202         173        mpfi       3.58   2.87              8.8         134
# 203         145         idi       3.01   3.40             23.0         106
# 204         141        mpfi       3.78   3.15              9.5         114
#
#     peakrpm  citympg  highwaympg    price
# 0      5000       21          27  13495.0
# 1      5000       21          27  16500.0
# 2      5000       19          26  16500.0
# 3      5500       24          30  13950.0
# 4      5500       18          22  17450.0
# ..      ...      ...         ...      ...
# 200    5400       23          28  16845.0
# 201    5300       19          25  19045.0
# 202    5500       18          23  21485.0
# 203    4800       26          27  22470.0
# 204    5400       19          25  22625.0
#
# [205 rows x 25 columns]

# %%
df['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
#        'mazda glc deluxe', 'mazda 626', 'mazda glc', 'mazda rx-7 gs',
#        'mazda glc 4', 'mazda glc custom l', 'mazda glc custom',
#        'buick electra 225 custom', 'buick century luxus (sw)',
#        'buick century', 'buick skyhawk', 'buick opel isuzu deluxe',
#        'buick skylark', 'buick century special',
#        'buick regal sport coupe (turbo)', 'mercury cougar',
#        'mitsubishi mirage', 'mitsubishi lancer', 'mitsubishi outlander',
#        'mitsubishi g4', 'mitsubishi mirage g4', 'mitsubishi montero',
#        'mitsubishi pajero', 'Nissan versa', 'nissan gt-r', 'nissan rogue',
#        'nissan latio', 'nissan titan', 'nissan leaf', 'nissan juke',
#        'nissan note', 'nissan clipper', 'nissan nv200', 'nissan dayz',
#        'nissan fuga', 'nissan otti', 'nissan teana', 'nissan kicks',
#        'peugeot 504', 'peugeot 304', 'peugeot 504 (sw)', 'peugeot 604sl',
#        'peugeot 505s turbo diesel', 'plymouth fury iii',
#        'plymouth cricket', 'plymouth satellite custom (sw)',
#        'plymouth fury gran sedan', 'plymouth valiant', 'plymouth duster',
#        'porsche macan', 'porcshce panamera', 'porsche cayenne',
#        'porsche boxter', 'renault 12tl', 'renault 5 gtl', 'saab 99e',
#        'saab 99le', 'saab 99gle', 'subaru', 'subaru dl', 'subaru brz',
#        'subaru baja', 'subaru r1', 'subaru r2', 'subaru trezia',
#        'subaru tribeca', 'toyota corona mark ii', 'toyota corona',
#        'toyota corolla 1200', 'toyota corona hardtop',
#        'toyota corolla 1600 (sw)', 'toyota carina', 'toyota mark ii',
#        'toyota corolla', 'toyota corolla liftback',
#        'toyota celica gt liftback', 'toyota corolla tercel',
#        'toyota corona liftback', 'toyota starlet', 'toyota tercel',
#        'toyota cressida', 'toyota celica gt', 'toyouta tercel',
#        'vokswagen rabbit', 'volkswagen 1131 deluxe sedan',
#        'volkswagen model 111', 'volkswagen type 3', 'volkswagen 411 (sw)',
#        'volkswagen super beetle', 'volkswagen dasher', 'vw dasher',
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'], dtype=object)

# %%
df['CarName'].value_counts().to_frame().head()
# Out:
#                       CarName
# toyota corona               6
# toyota corolla              6
# peugeot 504                 6
# subaru dl                   4
# mitsubishi mirage g4        3

# %%
df['fueltype'].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
df.describe()
# Out:
#         symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %% [markdown]
# #### cars and their fuel type

# %%
#cars and their fuel type 

z=df.groupby('CarName')['fueltype'].max()
x=z.sort_values(ascending=False)
print(x.value_counts())
print()
x.to_frame().head()
# Out:
# gas       134
# diesel     13
# Name: fueltype, dtype: int64
#                                fueltype
# CarName
# Nissan versa                        gas
# porsche cayenne                     gas
# plymouth fury gran sedan            gas
# plymouth fury iii                   gas
# plymouth satellite custom (sw)      gas

# %%
#How many cars have fuel type diesel and gas

x=(df['fueltype']=='diesel').sum()
print("diesel type fuel:",x)
print()
y=(df['fueltype']=='gas').sum()
print("gas type fuel:",y)
# Out:
# diesel type fuel: 20
#
# gas type fuel: 185

# %%
#cars with fuel type gas.

z = df.groupby('CarName')['fueltype'].max()
filtered_cars1 = z[z == 'gas']
print(filtered_cars1.value_counts())
print()
filtered_cars1.to_frame().head(10)
# Out:
# gas    134
# Name: fueltype, dtype: int64
#                          fueltype
# CarName
# Nissan versa                  gas
# alfa-romero Quadrifoglio      gas
# alfa-romero giulia            gas
# alfa-romero stelvio           gas
# audi 100 ls                   gas
# audi 100ls                    gas
# audi 4000                     gas
# audi 5000                     gas
# audi 5000s (diesel)           gas
# audi fox                      gas

# %%
#cars with fuel type diesel

z = df.groupby('CarName')['fueltype'].max()
filtered_cars2 = z[z == 'diesel']
print(filtered_cars2.value_counts())
print()
filtered_cars2.to_frame()
# Out:
# diesel    13
# Name: fueltype, dtype: int64
#                           fueltype
# CarName
# buick century               diesel
# buick century luxus (sw)    diesel
# buick electra 225 custom    diesel
# buick skyhawk               diesel
# nissan gt-r                 diesel
# peugeot 304                 diesel
# peugeot 505s turbo diesel   diesel
# toyota celica gt            diesel
# vokswagen rabbit            diesel
# volkswagen model 111        diesel
# volkswagen rabbit custom    diesel
# volkswagen super beetle     diesel
# volvo 246                   diesel

# %%
#plot for fuel type
fuel_count= df['fueltype'].value_counts()
plt.figure(figsize = (4,4))
sns.countplot(x='fueltype',data =df,order=fuel_count.index, palette = 'magma')
plt.title("cars with different fuel type");

# %% [markdown]
# #### cars with aspiration

# %%
df['aspiration'].unique()
# Out:
# array(['std', 'turbo'], dtype=object)

# %%
#How many cars have aspiration type standard and turbo

x=(df['aspiration']=='std').sum()
print("aspiration type standard:",x)
print()
y=(df['aspiration']=='turbo').sum()
print("aspiration type turbo:",y)
# Out:
# aspiration type standard: 168
#
# aspiration type turbo: 37

# %%
#cars and their aspiration

x=df.groupby('CarName')['aspiration'].max()
z=x.sort_values(ascending=False)
print(z.value_counts())
print()
z.to_frame().head()
# Out:
# std      116
# turbo     31
# Name: aspiration, dtype: int64
#                          aspiration
# CarName
# mitsubishi outlander          turbo
# mitsubishi g4                 turbo
# buick electra 225 custom      turbo
# plymouth cricket              turbo
# plymouth duster               turbo

# %%
#cars with aspiration as turbo

x=df.groupby('CarName')['aspiration'].max()
x=x[x=='turbo']
print(x.value_counts())
print()
x.to_frame()
# Out:
# turbo    31
# Name: aspiration, dtype: int64
#                           aspiration
# CarName
# audi 4000                      turbo
# audi 5000s (diesel)            turbo
# buick century                  turbo
# buick century luxus (sw)       turbo
# buick electra 225 custom       turbo
# buick skyhawk                  turbo
# dodge coronet custom           turbo
# dodge coronet custom (sw)      turbo
# dodge d200                     turbo
# mercury cougar                 turbo
# mitsubishi g4                  turbo
# mitsubishi mirage g4           turbo
# mitsubishi outlander           turbo
# nissan kicks                   turbo
# peugeot 304                    turbo
# peugeot 504                    turbo
# peugeot 505s turbo diesel      turbo
# peugeot 604sl                  turbo
# plymouth cricket               turbo
# plymouth duster                turbo
# saab 99e                       turbo
# saab 99gle                     turbo
# subaru dl                      turbo
# subaru r2                      turbo
# toyota celica gt               turbo
# volkswagen rabbit custom       turbo
# volkswagen super beetle        turbo
# volvo 144ea                    turbo
# volvo 246                      turbo
# volvo 264gl                    turbo
# volvo diesel                   turbo

# %%
#cars with standard aspiration 

x=df.groupby('CarName')['aspiration'].max()
x=x[x=='std']
print(x.value_counts())
print()
x.to_frame().head(10)
# Out:
# std    116
# Name: aspiration, dtype: int64
#                          aspiration
# CarName
# Nissan versa                    std
# alfa-romero Quadrifoglio        std
# alfa-romero giulia              std
# alfa-romero stelvio             std
# audi 100 ls                     std
# audi 100ls                      std
# audi 5000                       std
# audi fox                        std
# bmw 320i                        std
# bmw x1                          std

# %%
#Visualization for aspiration
aspira_count= df['aspiration'].value_counts()
plt.figure(figsize=(4,4))
sns.countplot(x='aspiration',data=df,order=aspira_count.index,palette='viridis')
plt.title("cars with different aspirations");

# %% [markdown]
# #### Car with door name

# %%
df['doornumber'].unique()
# Out:
# array(['two', 'four'], dtype=object)

# %%
#cars with different doornumber.

y=(df['doornumber']=='two').sum()
print("cars with two doors ",y)
print()
z=(df['doornumber']=='four').sum()
print("cars with four doors ",z)
# Out:
# cars with two doors  90
#
# cars with four doors  115

# %%
#cars with door numbers

x=df.groupby('CarName')['doornumber'].max()
z=x.sort_values(ascending=False)
print(z.value_counts())
print()
z.to_frame().head()
# Out:
# two     75
# four    72
# Name: doornumber, dtype: int64
#                   doornumber
# CarName
# Nissan versa             two
# plymouth fury iii        two
# plymouth cricket         two
# nissan teana             two
# nissan rogue             two

# %%
#cars with two doors

x=df.groupby('CarName')['doornumber'].max()
x=x[x=='two']
print(x.value_counts())
print()
x.to_frame().head(10)
# Out:
# two    75
# Name: doornumber, dtype: int64
#                          doornumber
# CarName
# Nissan versa                    two
# alfa-romero Quadrifoglio        two
# alfa-romero giulia              two
# alfa-romero stelvio             two
# audi 5000s (diesel)             two
# audi fox                        two
# bmw 320i                        two
# bmw x1                          two
# bmw x5                          two
# buick century                   two

# %%
#cars with four doors

x=df.groupby('CarName')['doornumber'].max()
x=x[x=='four']
print(x.value_counts())
print()
x.to_frame().head(10)
# Out:
# four    72
# Name: doornumber, dtype: int64
#                          doornumber
# CarName
# audi 100 ls                    four
# audi 100ls                     four
# audi 4000                      four
# audi 5000                      four
# bmw x3                         four
# bmw x4                         four
# bmw z4                         four
# buick century luxus (sw)       four
# buick century special          four
# buick electra 225 custom       four

# %%
#visualization for doornumbers of cars.

door_count= df['doornumber'].value_counts()
plt.figure(figsize=(4,4))
sns.countplot(x='doornumber',data=df,order=door_count.index,palette='viridis')
plt.title("cars with different door number");

# %% [markdown]
# #### Cars with carbody

# %%
#carbody

df['carbody'].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
#cars with different carbodies

y = df.groupby('CarName')['carbody'].max()
y = y.sort_values(ascending= False)
y.to_frame()
# Out:
#                                carbody
# CarName
# subaru trezia                    wagon
# subaru tribeca                   wagon
# peugeot 505s turbo diesel        wagon
# toyota corona hardtop            wagon
# peugeot 504 (sw)                 wagon
# ...                                ...
# porsche boxter             convertible
# toyota cressida            convertible
# alfa-romero stelvio        convertible
# alfa-romero giulia         convertible
# vw dasher                  convertible
#
# [147 rows x 1 columns]

# %%
#unique cars with different car bodies

y = df.groupby('CarName')['carbody'].max()
x = y[y=='wagon']
c = y[y=='hatchback']
d = y[y=='sedan']
f = y[y=='hardtop']
g = y[y=='convertible']

print('number of cars with body type as', x.value_counts())
print()
print('number of cars with body type as',c.value_counts())
print()
print('number of cars with body type as',d.value_counts())
print()
print('number of cars with body type as',f.value_counts())
print()
print('number of cars with body type as',g.value_counts())
# Out:
# number of cars with body type as wagon    23
# Name: carbody, dtype: int64
#
# number of cars with body type as hatchback    36
# Name: carbody, dtype: int64
#
# number of cars with body type as sedan    77
# Name: carbody, dtype: int64
#
# number of cars with body type as hardtop    5
# Name: carbody, dtype: int64
#
# number of cars with body type as convertible    6
# Name: carbody, dtype: int64

# %%
o = (df['carbody']=='hatchback').sum()
f = (df['carbody']=='sedan').sum()
g = (df['carbody']=='hardtop').sum()
h = (df['carbody']=='convertible').sum()
j = (df['carbody']=='wagon').sum()

print('sedan:',f,'hardtop:',g,'hatchback:',o,'convertible:',h,'wagon:',j)
# Out:
# sedan: 96 hardtop: 8 hatchback: 70 convertible: 6 wagon: 25

# %%
body_count= df['carbody'].value_counts()
plt.figure(figsize=(4,4))
sns.countplot(x='carbody',data=df,order=body_count.index,palette='viridis')
plt.xticks(rotation=90)
plt.title("cars with different car body");

# %% [markdown]
# #### Cars having different drivewheel

# %%
#cars having drivewheel
df['drivewheel'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
o= (df['drivewheel']=='rwd').sum()
y=(df['drivewheel']=='fwd').sum()
t =(df['drivewheel']=='4wd').sum()

print("cars with rear wheel drive:",o)
print()
print("cars with front wheel drive:",y)
print()
print("cars with 4 wheel drive:",t)
# Out:
# cars with rear wheel drive: 76
#
# cars with front wheel drive: 120
#
# cars with 4 wheel drive: 9

# %%
h = df.groupby('CarName')['drivewheel'].max()
h.sort_values(ascending=False)
h.to_frame()
# Out:
#                          drivewheel
# CarName
# Nissan versa                    fwd
# alfa-romero Quadrifoglio        rwd
# alfa-romero giulia              rwd
# alfa-romero stelvio             rwd
# audi 100 ls                     fwd
# ...                             ...
# volvo 246                       rwd
# volvo 264gl                     rwd
# volvo diesel                    rwd
# vw dasher                       fwd
# vw rabbit                       fwd
#
# [147 rows x 1 columns]

# %% [markdown]
# #### wheel base of cars

# %%
#wheel base of cars
df['wheelbase'].describe()
# Out:
# count    205.000000
# mean      98.756585
# std        6.021776
# min       86.600000
# 25%       94.500000
# 50%       97.000000
# 75%      102.400000
# max      120.900000
# Name: wheelbase, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['wheelbase'],color='olivedrab')
plt.title("car wheels distribution plot");

# %% [markdown]
# so from the above plot we conclude that most of the cars have low wheel base.
# 75% wheelbase are around 102  or we can say 25% wheelbase are in between 102 to 120.

# %% [markdown]
# #### Car length of cars

# %%
#Car length of cars
df['carlength'].describe()
# Out:
# count    205.000000
# mean     174.049268
# std       12.337289
# min      141.100000
# 25%      166.300000
# 50%      173.200000
# 75%      183.100000
# max      208.100000
# Name: carlength, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['carlength'])
plt.title('car distribution plot for car lengths');

# %% [markdown]
# most of the car lengths are in between range 160 to 190.
#
# 25% car lengths are in between 183 to above 200.

# %% [markdown]
# #### Car width of cars

# %%
#car width of cars
df['carwidth'].describe()
# Out:
# count    205.000000
# mean      65.907805
# std        2.145204
# min       60.300000
# 25%       64.100000
# 50%       65.500000
# 75%       66.900000
# max       72.300000
# Name: carwidth, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['carwidth'])
plt.title("car distribution plot for car width");

# %% [markdown]
# most of the car width are between 65.5 to 66
#
# only a 25% car width are between 67 and 72.

# %% [markdown]
# #### Cars (Height,CurbWeight,Engine Size)

# %%
print("CAR HEIGHT")
print()
print(df['carheight'].describe())
print()
print("CURB WEIGHT")
print()
print(df['curbweight'].describe())
print()
print("ENGINE SIZE")
print()
print(df['enginesize'].describe())
# Out:
# CAR HEIGHT
#
# count    205.000000
# mean      53.724878
# std        2.443522
# min       47.800000
# 25%       52.000000
# 50%       54.100000
# 75%       55.500000
# max       59.800000
# Name: carheight, dtype: float64
#
# CURB WEIGHT
#
# count     205.000000
# mean     2555.565854
# std       520.680204
# min      1488.000000
# 25%      2145.000000
# 50%      2414.000000
# 75%      2935.000000
# max      4066.000000
# Name: curbweight, dtype: float64
#
# ENGINE SIZE
#
# count    205.000000
# mean     126.907317
# std       41.642693
# min       61.000000
# 25%       97.000000
# 50%      120.000000
# 75%      141.000000
# max      326.000000
# Name: enginesize, dtype: float64

# %% [markdown]
# #### Location of Engine in Cars.

# %%
#engine location of cars
df['enginelocation'].unique()
# Out:
# array(['front', 'rear'], dtype=object)

# %% [markdown]
# #### cylinder number

# %%
# cylinder number
df['cylindernumber'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %% [markdown]
# #### Cars with(top prices,citympg,highwaympg,carcompanies,peak rpm,horse power)

# %%
#Cars with top prices.
y=df.groupby(['CarName'])['price'].max()
v=y.sort_values(ascending=False).head(20)
v.to_frame()
# Out:
#                                    price
# CarName
# buick regal sport coupe (turbo)  45400.0
# bmw x5                           41315.0
# buick century special            40960.0
# porsche boxter                   37028.0
# bmw x3                           36880.0
# jaguar xk                        36000.0
# jaguar xf                        35550.0
# buick skylark                    35056.0
# buick opel isuzu deluxe          34184.0
# porsche cayenne                  34028.0
# porcshce panamera                32528.0
# jaguar xj                        32250.0
# buick skyhawk                    31600.0
# bmw x4                           30760.0
# buick century luxus (sw)         28248.0
# buick century                    28176.0
# buick electra 225 custom         25552.0
# bmw z4                           24565.0
# audi 4000                        23875.0
# volvo 264gl                      22625.0

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=v.index,y=v,palette='magma')
plt.title("Most expensive Cars (top 20)")
plt.xticks(rotation=90);

# %%
#car companies with prices of all their cars

y=df.groupby(['CarName'])['price'].sum()
v=y.sort_values(ascending=False).head(20)
v.to_frame()
# Out:
#                                    price
# CarName
# peugeot 504                      92615.0
# porsche cayenne                  65428.5
# bmw x3                           57985.0
# toyota corolla                   57180.0
# toyota corona                    56198.0
# buick regal sport coupe (turbo)  45400.0
# bmw x5                           41315.0
# volvo 264gl                      41045.0
# buick century special            40960.0
# volvo 244dl                      37470.0
# porsche boxter                   37028.0
# jaguar xk                        36000.0
# jaguar xf                        35550.0
# audi 100ls                       35160.0
# buick skylark                    35056.0
# peugeot 604sl                    35050.0
# subaru dl                        34363.0
# buick opel isuzu deluxe          34184.0
# mitsubishi mirage g4             33727.0
# saab 99gle                       33660.0

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=v.index,y=v,palette='cividis')
plt.title("Car companies with their total expenses(top 20)")
plt.xticks(rotation=90);

# %%
#Top horsepower of cars
f=df.groupby(['CarName'])['horsepower'].max()
f=f.sort_values(ascending=False).head(20)
f.to_frame()
# Out:
#                                  horsepower
# CarName
# porsche cayenne                         288
# jaguar xk                               262
# porsche boxter                          207
# porcshce panamera                       207
# nissan kicks                            200
# buick regal sport coupe (turbo)         184
# buick century special                   184
# bmw x3                                  182
# bmw x5                                  182
# bmw x4                                  182
# jaguar xj                               176
# jaguar xf                               176
# mercury cougar                          175
# volvo 264gl                             162
# volvo diesel                            162
# toyota corona                           161
# toyota corolla liftback                 161
# volvo 144ea                             160
# nissan teana                            160
# saab 99gle                              160

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=f.index,y=f,palette='viridis_r')
plt.title("Car with most horsepower(top 20)")
plt.xticks(rotation=90);

# %%
#cars with top RPM

f=df.groupby(['CarName'])['peakrpm'].max()
f=f.sort_values(ascending=False).head(20)
f.to_frame()
# Out:
#                            peakrpm
# CarName
# toyota corolla tercel         6600
# toyota celica gt liftback     6600
# mazda rx-7 gs                 6000
# honda accord cvcc             6000
# honda civic 1500 gl           6000
# honda civic cvcc              6000
# mazda 626                     6000
# mazda glc                     6000
# mazda glc 4                   6000
# honda accord lx               6000
# porcshce panamera             5900
# porsche boxter                5900
# porsche cayenne               5900
# bmw 320i                      5800
# honda prelude                 5800
# honda accord                  5800
# honda civic                   5800
# honda civic 1300              5800
# peugeot 604sl                 5600
# dodge rampage                 5500

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=f.index,y=f,palette='mako_r')
plt.title("Car with top RPM(top 20)")
plt.xticks(rotation=90);

# %%
#Cars with the best Mileage on Highway.

f=df.groupby(['CarName'])['highwaympg'].max()
f=f.sort_values(ascending=False).head(20)
f.to_frame()
# Out:
#                          highwaympg
# CarName
# honda civic                      54
# chevrolet impala                 53
# nissan gt-r                      50
# toyota corolla                   47
# toyota corona                    47
# volkswagen model 111             46
# vokswagen rabbit                 46
# isuzu D-Max V-Cross              43
# chevrolet vega 2300              43
# chevrolet monte carlo            43
# isuzu D-Max                      43
# volkswagen super beetle          42
# mazda glc deluxe                 42
# mitsubishi mirage                41
# plymouth fury iii                41
# dodge rampage                    41
# mazda rx-7 gs                    39
# toyota corona mark ii            39
# toyota corolla 1200              38
# dodge monaco (sw)                38

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=f.index,y=f,palette='cividis_r')
plt.title("Car with best Mileage on highway (top 20)")
plt.xticks(rotation=90);

# %%
#Cars with the best Mileage in city.

f=df.groupby(['CarName'])['citympg'].max()
f=f.sort_values(ascending=False).head(20)
f.to_frame()
# Out:
#                           citympg
# CarName
# honda civic                    49
# chevrolet impala               47
# nissan gt-r                    45
# toyota corona                  38
# chevrolet monte carlo          38
# chevrolet vega 2300            38
# toyota corolla                 38
# isuzu D-Max                    38
# isuzu D-Max V-Cross            38
# dodge rampage                  37
# vokswagen rabbit               37
# plymouth fury iii              37
# volkswagen model 111           37
# volkswagen super beetle        37
# mitsubishi mirage              37
# mazda glc deluxe               36
# toyota corona mark ii          35
# volkswagen rabbit custom       33
# subaru                         32
# maxda glc deluxe               31

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=f.index,y=f,palette='gist_earth')
plt.title("Car with best Mileage in city (top 20)")
plt.xticks(rotation=90);

# %% [markdown]
# ####  Price vs engine type  ,  Price vs Fuel system

# %%
df['enginetype'].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'ohcf', 'dohcv'], dtype=object)

# %%
df['fuelsystem'].unique()
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', '4bbl', 'idi', 'spdi'],
#       dtype=object)

# %%
#price Vs engine type

plt.figure(figsize=(10,5))
sns.boxplot(x='enginetype',y='price',data=df,palette='viridis_r')
plt.xticks(rotation=90);

# %%
#price vs fuel system
plt.figure(figsize=(10,5))
sns.boxplot(x='fuelsystem',y='price',data=df,palette='inferno_r')
plt.xticks(rotation=90);
